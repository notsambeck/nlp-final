# %%
import numpy as np

# %%
import checklist
from checklist.test_suite import TestSuite
import logging
logging.basicConfig(level=logging.ERROR)

# %%
from transformers import pipeline

# %%
model = pipeline("question-answering", "./model/", device=0)

# %%
suite_path = '../../../checklist/release_data/squad/squad_suite.pkl'
suite = TestSuite.from_file(suite_path)

# %%
def predconfs(context_question_pairs):
    preds = []
    confs = []
    for c, q in context_question_pairs:
        try:
            p = model(question=q, context=c, truncation=True, )
        except:
            print('Failed', q)
            preds.append(' ')
            confs.append(1)
        preds.append(p['answer'])
        confs.append(p['score'])
    return preds, np.array(confs)

# %%
suite.run(predconfs, overwrite=True, n=100)   # for quicker testing
# Out:
# Running A is COMP than B. Who is more / less COMP?
# Predicting 200 examples
# Running Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Predicting 1200 examples
# Running size, shape, age, color
# Predicting 400 examples
# Running Profession vs nationality
# Predicting 1000 examples
# Running Animal vs Vehicle
# Predicting 400 examples
# Running Animal vs Vehicle v2
# Predicting 400 examples
# Running Synonyms
# Predicting 400 examples
# Running A is COMP than B. Who is antonym(COMP)? B
# Predicting 400 examples
# Running A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Predicting 1600 examples
# Running Question typo
# Predicting 200 examples
# Running Question contractions
# Predicting 201 examples
# Running Add random sentence to context
# Predicting 300 examples
# Running Change name everywhere
# Predicting 1100 examples
# Running Change location everywhere
# Predicting 1100 examples
# Running There was a change in profession
# Predicting 200 examples
# Running Understanding before / after -> first / last.
# Predicting 400 examples
# Running Negation in context, may or may not be in question
# Predicting 400 examples
# Running Negation in question only.
# Predicting 800 examples
# Running M/F failure rates should be similar for different professions
# Predicting 100 examples
# Running Basic coref, he / she
# Predicting 800 examples
# Running Basic coref, his / her
# Predicting 200 examples
# Running Former / Latter
# Predicting 400 examples
# Running Agent / object distinction
# Predicting 400 examples
# Running Agent / object distinction with 3 agents
# Predicting 1600 examples

# %%
def format_squad_with_context(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'C: %s\nQ: %s\n' % (c, q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret

# %%
suite.summary(format_example_fn=format_squad_with_context)
# Out:
# Vocabulary
#
# A is COMP than B. Who is more / less COMP?
# Test cases:      494
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Amber is cleaner than Steven.
# Q: Who is less clean?
# A: Steven
# P: Amber
#
#
# ----
# C: Daniel is cleaner than Heather.
# Q: Who is less clean?
# A: Heather
# P: Daniel
#
#
# ----
# C: Kelly is younger than Natalie.
# Q: Who is less young?
# A: Natalie
# P: Kelly
#
#
# ----
#
#
# Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Test cases:      497
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Kayla is extremely concerned about the project. Justin is concerned about the project.
# Q: Who is least concerned about the project?
# A: Justin
# P: Kayla
#
# C: Kayla is concerned about the project. Justin is mildly concerned about the project.
# Q: Who is least concerned about the project?
# A: Justin
# P: Kayla
#
# C: Kayla is extremely concerned about the project. Justin is mildly concerned about the project.
# Q: Who is least concerned about the project?
# A: Justin
# P: Kayla
#
#
# ----
# C: Sarah is super vocal about the project. Amanda is vocal about the project.
# Q: Who is least vocal about the project?
# A: Amanda
# P: Sarah
#
# C: Sarah is vocal about the project. Amanda is slightly vocal about the project.
# Q: Who is least vocal about the project?
# A: Amanda
# P: Sarah
#
# C: Sarah is super vocal about the project. Amanda is slightly vocal about the project.
# Q: Who is least vocal about the project?
# A: Amanda
# P: Sarah
#
#
# ----
# C: Brandon is incredibly excited about the project. Joseph is excited about the project.
# Q: Who is least excited about the project?
# A: Joseph
# P: Brandon
#
# C: Joseph is excited about the project. Brandon is incredibly excited about the project.
# Q: Who is least excited about the project?
# A: Joseph
# P: Brandon
#
# C: Joseph is mildly excited about the project. Brandon is incredibly excited about the project.
# Q: Who is least excited about the project?
# A: Joseph
# P: Brandon
#
#
# ----
#
#
#
#
# Taxonomy
#
# size, shape, age, color
# Test cases:      500
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: There is a thing in the room. The thing is big and yellow.
# Q: What size is the thing?
# A: big
# P: big and yellow
#
# C: There is a thing in the room. The thing is big and yellow.
# Q: What color is the thing?
# A: yellow
# P: big and yellow
#
# C: There is a big yellow thing in the room.
# Q: What size is the thing?
# A: big
# P: yellow
#
#
# ----
# C: There is an object in the room. The object is big and purple.
# Q: What size is the object?
# A: big
# P: big and purple
#
# C: There is an object in the room. The object is big and purple.
# Q: What color is the object?
# A: purple
# P: big and purple
#
# C: There is a big purple object in the room.
# Q: What size is the object?
# A: big
# P: big purple
#
#
# ----
# C: There is a toy in the room. The toy is enormous and white.
# Q: What size is the toy?
# A: enormous
# P: enormous and white
#
# C: There is an enormous white toy in the room.
# Q: What size is the toy?
# A: enormous
# P: white
#
#
# ----
#
#
# Profession vs nationality
# Test cases:      500
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Jamie is an agent and Nigerian.
# Q: What is Jamie's job?
# A: agent
# P: agent and Nigerian
#
#
# ----
# C: Eric is an analyst and Bangladeshi.
# Q: What is Eric's job?
# A: analyst
# P: analyst and Bangladeshi
#
#
# ----
# C: Richard is an artist and Pakistani.
# Q: What is Richard's job?
# A: artist
# P: artist and Pakistani
#
#
# ----
#
#
# Animal vs Vehicle
# Test cases:      500
# Test cases run:  100
# Fails (rate):    81 (81.0%)
#
# Example fails:
# C: Natalie has a dog and a train.
# Q: What vehicle does Natalie have?
# A: train
# P: dog
#
#
# ----
# C: Kelly has a cow and a firetruck.
# Q: What vehicle does Kelly have?
# A: firetruck
# P: a cow
#
#
# ----
# C: Rachel has a duck and a bike.
# Q: What vehicle does Rachel have?
# A: bike
# P: a duck and a bike
#
#
# ----
#
#
# Animal vs Vehicle v2
# Test cases:      496
# Test cases run:  100
# Fails (rate):    84 (84.0%)
#
# Example fails:
# C: Shannon bought a truck. Michelle bought a bull.
# Q: Who bought an animal?
# A: Michelle
# P: Michelle bought a bull
#
#
# ----
# C: Andrew bought a minivan. Patrick bought a cow.
# Q: Who bought a vehicle?
# A: Andrew
# P: Patrick
#
#
# ----
# C: Kyle bought a hamster. Sean bought a firetruck.
# Q: Who bought an animal?
# A: Kyle
# P: Sean
#
# C: Sean bought a firetruck. Kyle bought a hamster.
# Q: Who bought a vehicle?
# A: Sean
# P: Kyle
#
#
# ----
#
#
# Synonyms
# Test cases:      447
# Test cases run:  100
# Fails (rate):    56 (56.0%)
#
# Example fails:
# C: Katherine is very intelligent. Kimberly is very happy.
# Q: Who is joyful?
# A: Kimberly
# P: Katherine
#
# C: Kimberly is very happy. Katherine is very intelligent.
# Q: Who is smart?
# A: Katherine
# P: Kimberly
#
#
# ----
# C: Sophia is very courageous. Kevin is very spiritual.
# Q: Who is religious?
# A: Kevin
# P: Sophia
#
#
# ----
# C: Anna is very religious. Rachel is very brave.
# Q: Who is courageous?
# A: Rachel
# P: Anna
#
# C: Rachel is very brave. Anna is very religious.
# Q: Who is spiritual?
# A: Anna
# P: Rachel
#
#
# ----
#
#
# A is COMP than B. Who is antonym(COMP)? B
# Test cases:      496
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Samuel is slower than Kimberly.
# Q: Who is faster?
# A: Kimberly
# P: Samuel
#
# C: Kimberly is faster than Samuel.
# Q: Who is slower?
# A: Samuel
# P: Kimberly
#
#
# ----
# C: Tiffany is worse than Zachary.
# Q: Who is better?
# A: Zachary
# P: Tiffany
#
# C: Zachary is better than Tiffany.
# Q: Who is worse?
# A: Tiffany
# P: Zachary
#
#
# ----
# C: Joshua is taller than Daniel.
# Q: Who is shorter?
# A: Daniel
# P: Joshua
#
# C: Daniel is shorter than Joshua.
# Q: Who is taller?
# A: Joshua
# P: Daniel
#
#
# ----
#
#
# A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Test cases:      491
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Nicholas is less powerless than Kyle.
# Q: Who is more powerless?
# A: Kyle
# P: Nicholas
#
# C: Kyle is less powerful than Nicholas.
# Q: Who is more powerful?
# A: Nicholas
# P: Kyle
#
# C: Nicholas is more powerful than Kyle.
# Q: Who is less powerful?
# A: Kyle
# P: Nicholas
#
#
# ----
# C: Samantha is more invisible than Christian.
# Q: Who is less invisible?
# A: Christian
# P: Samantha
#
# C: Samantha is less visible than Christian.
# Q: Who is more visible?
# A: Christian
# P: Samantha
#
# C: Christian is less invisible than Samantha.
# Q: Who is more invisible?
# A: Samantha
# P: Christian
#
#
# ----
# C: Christina is more optimistic than Alexander.
# Q: Who is less optimistic?
# A: Alexander
# P: Christina
#
# C: Christina is less pessimistic than Alexander.
# Q: Who is more pessimistic?
# A: Alexander
# P: Christina
#
# C: Christina is less pessimistic than Alexander.
# Q: Who is less optimistic?
# A: Alexander
# P: Christina
#
#
# ----
#
#
#
#
# Robustness
#
# Question typo
# Test cases:      500
# Test cases run:  100
# Fails (rate):    12 (12.0%)
#
# Example fails:
# C: In 1271, Kublai Khan imposed the name Great Yuan (Chinese: 大元; pinyin: Dà Yuán; Wade–Giles: Ta-Yüan), establishing the Yuan dynasty. "Dà Yuán" (大元) is from the sentence "大哉乾元" (dà zai Qián Yuán / "Great is Qián, the Primal") in the Commentaries on the Classic of Changes (I Ching) section regarding Qián (乾). The counterpart in Mongolian language was Dai Ön Ulus, also rendered as Ikh Yuan Üls or Yekhe Yuan Ulus. In Mongolian, Dai Ön (Great Yuan) is often used in conjunction with the "Yeke Mongghul Ulus" (lit. "Great Mongol State"), resulting in Dai Ön Yeke Mongghul Ulus (Mongolian script: ), meaning "Great Yuan Great Mongol State". The Yuan dynasty is also known as the "Mongol dynasty" or "Mongol Dynasty of China", similar to the names "Manchu dynasty" or "Manchu Dynasty of China" for the Qing dynasty. Furthermore, the Yuan is sometimes known as the "Empire of the Great Khan" or "Khanate of the Great Khan", which particularly appeared on some Yuan maps, since Yuan emperors held the nominal title of Great Khan. Nevertheless, both terms can also refer to the khanate within the Mongol Empire directly ruled by Great Khans before the actual establishment of the Yuan dynasty by Kublai Khan in 1271.
# Q: What writing inspired the name Great Yuan?
# P: I Ching)
#
# C: In 1271, Kublai Khan imposed the name Great Yuan (Chinese: 大元; pinyin: Dà Yuán; Wade–Giles: Ta-Yüan), establishing the Yuan dynasty. "Dà Yuán" (大元) is from the sentence "大哉乾元" (dà zai Qián Yuán / "Great is Qián, the Primal") in the Commentaries on the Classic of Changes (I Ching) section regarding Qián (乾). The counterpart in Mongolian language was Dai Ön Ulus, also rendered as Ikh Yuan Üls or Yekhe Yuan Ulus. In Mongolian, Dai Ön (Great Yuan) is often used in conjunction with the "Yeke Mongghul Ulus" (lit. "Great Mongol State"), resulting in Dai Ön Yeke Mongghul Ulus (Mongolian script: ), meaning "Great Yuan Great Mongol State". The Yuan dynasty is also known as the "Mongol dynasty" or "Mongol Dynasty of China", similar to the names "Manchu dynasty" or "Manchu Dynasty of China" for the Qing dynasty. Furthermore, the Yuan is sometimes known as the "Empire of the Great Khan" or "Khanate of the Great Khan", which particularly appeared on some Yuan maps, since Yuan emperors held the nominal title of Great Khan. Nevertheless, both terms can also refer to the khanate within the Mongol Empire directly ruled by Great Khans before the actual establishment of the Yuan dynasty by Kublai Khan in 1271.
# Q: What writing inpsired the name Great Yuan?
# P: Classic of Changes (I Ching)
#
#
# ----
# C: The early United States expressed its opposition to Imperialism, at least in a form distinct from its own Manifest Destiny, through policies such as the Monroe Doctrine. However, beginning in the late 19th and early 20th century, policies such as Theodore Roosevelt’s interventionism in Central America and Woodrow Wilson’s mission to "make the world safe for democracy" changed all this. They were often backed by military force, but were more often affected from behind the scenes. This is consistent with the general notion of hegemony and imperium of historical empires. In 1898, Americans who opposed imperialism created the Anti-Imperialist League to oppose the US annexation of the Philippines and Cuba. One year later, a war erupted in the Philippines causing business, labor and government leaders in the US to condemn America's occupation in the Philippines as they also denounced them for causing the deaths of many Filipinos. American foreign policy was denounced as a "racket" by Smedley Butler, an American general. He said, "Looking back on it, I might have given Al Capone a few hints. The best he could do was to operate his racket in three districts. I operated on three continents".
# Q: What caused the US public to condemn the occupation of the philippines?
# P: a war
#
# C: The early United States expressed its opposition to Imperialism, at least in a form distinct from its own Manifest Destiny, through policies such as the Monroe Doctrine. However, beginning in the late 19th and early 20th century, policies such as Theodore Roosevelt’s interventionism in Central America and Woodrow Wilson’s mission to "make the world safe for democracy" changed all this. They were often backed by military force, but were more often affected from behind the scenes. This is consistent with the general notion of hegemony and imperium of historical empires. In 1898, Americans who opposed imperialism created the Anti-Imperialist League to oppose the US annexation of the Philippines and Cuba. One year later, a war erupted in the Philippines causing business, labor and government leaders in the US to condemn America's occupation in the Philippines as they also denounced them for causing the deaths of many Filipinos. American foreign policy was denounced as a "racket" by Smedley Butler, an American general. He said, "Looking back on it, I might have given Al Capone a few hints. The best he could do was to operate his racket in three districts. I operated on three continents".
# Q: What caused the US public to condemn the occupation of the philippnies?
# P: a war erupted in the Philippines
#
#
# ----
# C: Next, the two plastid-dividing rings, or PD rings form. The inner plastid-dividing ring is located in the inner side of the chloroplast's inner membrane, and is formed first. The outer plastid-dividing ring is found wrapped around the outer chloroplast membrane. It consists of filaments about 5 nanometers across, arranged in rows 6.4 nanometers apart, and shrinks to squeeze the chloroplast. This is when chloroplast constriction begins.
# In a few species like Cyanidioschyzon merolæ, chloroplasts have a third plastid-dividing ring located in the chloroplast's intermembrane space.
# Q: What are PD rings?
# P: plastid-dividing rings
#
# C: Next, the two plastid-dividing rings, or PD rings form. The inner plastid-dividing ring is located in the inner side of the chloroplast's inner membrane, and is formed first. The outer plastid-dividing ring is found wrapped around the outer chloroplast membrane. It consists of filaments about 5 nanometers across, arranged in rows 6.4 nanometers apart, and shrinks to squeeze the chloroplast. This is when chloroplast constriction begins.
# In a few species like Cyanidioschyzon merolæ, chloroplasts have a third plastid-dividing ring located in the chloroplast's intermembrane space.
# Q: What are PD ring?s
# P: two plastid-dividing rings
#
#
# ----
#
#
# Question contractions
# Test cases:      500
# Test cases run:  100
# Fails (rate):    11 (11.0%)
#
# Example fails:
# C: Leukocytes (white blood cells) act like independent, single-celled organisms and are the second arm of the innate immune system. The innate leukocytes include the phagocytes (macrophages, neutrophils, and dendritic cells), mast cells, eosinophils, basophils, and natural killer cells. These cells identify and eliminate pathogens, either by attacking larger pathogens through contact or by engulfing and then killing microorganisms. Innate cells are also important mediators in the activation of the adaptive immune system.
# Q: What are three kinds of phagocytes?
# P: macrophages, neutrophils, and dendritic cells
#
# C: Leukocytes (white blood cells) act like independent, single-celled organisms and are the second arm of the innate immune system. The innate leukocytes include the phagocytes (macrophages, neutrophils, and dendritic cells), mast cells, eosinophils, basophils, and natural killer cells. These cells identify and eliminate pathogens, either by attacking larger pathogens through contact or by engulfing and then killing microorganisms. Innate cells are also important mediators in the activation of the adaptive immune system.
# Q: What're three kinds of phagocytes?
# P: macrophages, neutrophils
#
#
# ----
# C: Rhodoplasts have a double membrane with an intermembrane space and phycobilin pigments organized into phycobilisomes on the thylakoid membranes, preventing their thylakoids from stacking. Some contain pyrenoids. Rhodoplasts have chlorophyll a and phycobilins for photosynthetic pigments; the phycobilin phycoerytherin is responsible for giving many red algae their distinctive red color. However, since they also contain the blue-green chlorophyll a and other pigments, many are reddish to purple from the combination. The red phycoerytherin pigment is an adaptation to help red algae catch more sunlight in deep water—as such, some red algae that live in shallow water have less phycoerytherin in their rhodoplasts, and can appear more greenish. Rhodoplasts synthesize a form of starch called floridean, which collects into granules outside the rhodoplast, in the cytoplasm of the red alga.
# Q: What is floridean?
# P: a form of starch
#
# C: Rhodoplasts have a double membrane with an intermembrane space and phycobilin pigments organized into phycobilisomes on the thylakoid membranes, preventing their thylakoids from stacking. Some contain pyrenoids. Rhodoplasts have chlorophyll a and phycobilins for photosynthetic pigments; the phycobilin phycoerytherin is responsible for giving many red algae their distinctive red color. However, since they also contain the blue-green chlorophyll a and other pigments, many are reddish to purple from the combination. The red phycoerytherin pigment is an adaptation to help red algae catch more sunlight in deep water—as such, some red algae that live in shallow water have less phycoerytherin in their rhodoplasts, and can appear more greenish. Rhodoplasts synthesize a form of starch called floridean, which collects into granules outside the rhodoplast, in the cytoplasm of the red alga.
# Q: What's floridean?
# P: starch
#
#
# ----
# C: Unlike animals, plants lack phagocytic cells, but many plant immune responses involve systemic chemical signals that are sent through a plant. Individual plant cells respond to molecules associated with pathogens known as Pathogen-associated molecular patterns or PAMPs. When a part of a plant becomes infected, the plant produces a localized hypersensitive response, whereby cells at the site of infection undergo rapid apoptosis to prevent the spread of the disease to other parts of the plant. Systemic acquired resistance (SAR) is a type of defensive response used by plants that renders the entire plant resistant to a particular infectious agent. RNA silencing mechanisms are particularly important in this systemic response as they can block virus replication.
# Q: What is a mechanism that can help plants block virus replication?
# P: RNA silencing mechanisms
#
# C: Unlike animals, plants lack phagocytic cells, but many plant immune responses involve systemic chemical signals that are sent through a plant. Individual plant cells respond to molecules associated with pathogens known as Pathogen-associated molecular patterns or PAMPs. When a part of a plant becomes infected, the plant produces a localized hypersensitive response, whereby cells at the site of infection undergo rapid apoptosis to prevent the spread of the disease to other parts of the plant. Systemic acquired resistance (SAR) is a type of defensive response used by plants that renders the entire plant resistant to a particular infectious agent. RNA silencing mechanisms are particularly important in this systemic response as they can block virus replication.
# Q: What's a mechanism that can help plants block virus replication?
# P: RNA silencing
#
#
# ----
#
#
# Add random sentence to context
# Test cases:      500
# Test cases run:  100
# Fails (rate):    16 (16.0%)
#
# Example fails:
# C: Though there is no official definition for the northern boundary of southern California, such a division has existed from the time when Mexico ruled California, and political disputes raged between the Californios of Monterey in the upper part and Los Angeles in the lower part of Alta California. Following the acquisition of California by the United States, the division continued as part of the attempt by several pro-slavery politicians to arrange the division of Alta California at 36 degrees, 30 minutes, the line of the Missouri Compromise. Instead, the passing of the Compromise of 1850 enabled California to be admitted to the Union as a free state, preventing southern California from becoming its own separate slave state.
# Q: The legislation allowed California to be admitted to the Union as what kind of state?
# P: free
#
# C: Today, this is known as the Miasma theory. Though there is no official definition for the northern boundary of southern California, such a division has existed from the time when Mexico ruled California, and political disputes raged between the Californios of Monterey in the upper part and Los Angeles in the lower part of Alta California. Following the acquisition of California by the United States, the division continued as part of the attempt by several pro-slavery politicians to arrange the division of Alta California at 36 degrees, 30 minutes, the line of the Missouri Compromise. Instead, the passing of the Compromise of 1850 enabled California to be admitted to the Union as a free state, preventing southern California from becoming its own separate slave state.
# Q: The legislation allowed California to be admitted to the Union as what kind of state?
# P: free state
#
#
# ----
# C: Oxygen is a chemical element with symbol O and atomic number 8. It is a member of the chalcogen group on the periodic table and is a highly reactive nonmetal and oxidizing agent that readily forms compounds (notably oxides) with most elements. By mass, oxygen is the third-most abundant element in the universe, after hydrogen and helium. At standard temperature and pressure, two atoms of the element bind to form dioxygen, a colorless and odorless diatomic gas with the formula O
# 2. Diatomic oxygen gas constitutes 20.8% of the Earth's atmosphere. However, monitoring of atmospheric oxygen levels show a global downward trend, because of fossil-fuel burning. Oxygen is the most abundant element by mass in the Earth's crust as part of oxide compounds such as silicon dioxide, making up almost half of the crust's mass.
# Q: Are atmospheric oxygen levels going up, down, or staying the same?
# P: downward trend
#
# C: Aeolian sand with a number of dunes parted by peat swamps or small ponds cover the highest terrace. Oxygen is a chemical element with symbol O and atomic number 8. It is a member of the chalcogen group on the periodic table and is a highly reactive nonmetal and oxidizing agent that readily forms compounds (notably oxides) with most elements. By mass, oxygen is the third-most abundant element in the universe, after hydrogen and helium. At standard temperature and pressure, two atoms of the element bind to form dioxygen, a colorless and odorless diatomic gas with the formula O
# 2. Diatomic oxygen gas constitutes 20.8% of the Earth's atmosphere. However, monitoring of atmospheric oxygen levels show a global downward trend, because of fossil-fuel burning. Oxygen is the most abundant element by mass in the Earth's crust as part of oxide compounds such as silicon dioxide, making up almost half of the crust's mass.
# Q: Are atmospheric oxygen levels going up, down, or staying the same?
# P: downward
#
#
# ----
# C: A few galleries were redesigned in the 1990s including the Indian, Japanese, Chinese, iron work, the main glass galleries and the main silverware gallery which was further enhanced in 2002 when some of the Victorian decoration was recreated. This included two of the ten columns having their ceramic decoration replaced and the elaborate painted designs restored on the ceiling. As part of the 2006 renovation the mosaic floors in the sculpture gallery were restored—most of the Victorian floors were covered in linoleum after the Second World War. After the success of the British Galleries, opened in 2001, it was decided to embark on a major redesign of all the galleries in the museum; this is known as "FuturePlan", and was created in consultation with the exhibition designers and masterplanners Metaphor. The plan is expected to take about ten years and was started in 2002. To date several galleries have been redesigned, notably, in 2002: the main Silver Gallery, Contemporary; in 2003: Photography, the main entrance, The Painting Galleries; in 2004: the tunnel to the subway leading to South Kensington tube station, New signage throughout the museum, architecture, V&A and RIBA reading rooms and stores, metalware, Members' Room, contemporary glass, the Gilbert Bayes sculpture gallery; in 2005: portrait miniatures, prints and drawings, displays in Room 117, the garden, sacred silver and stained glass; in 2006: Central Hall Shop, Islamic Middle East, the new café, sculpture galleries. Several designers and architects have been involved in this work. Eva Jiřičná designed the enhancements to the main entrance and rotunda, the new shop, the tunnel and the sculpture galleries. Gareth Hoskins was responsible for contemporary and architecture, Softroom, Islamic Middle East and the Members' Room, McInnes Usher McKnight Architects (MUMA) were responsible for the new Cafe and designed the new Medieval and Renaissance galleries which opened in 2009.
# Q: Who designed the new Medieval and Renaissance galleries which opened in 2009?
# P: McInnes Usher McKnight Architects
#
# C: Kenya has a warm and humid tropical climate on its Indian Ocean coastline. A few galleries were redesigned in the 1990s including the Indian, Japanese, Chinese, iron work, the main glass galleries and the main silverware gallery which was further enhanced in 2002 when some of the Victorian decoration was recreated. This included two of the ten columns having their ceramic decoration replaced and the elaborate painted designs restored on the ceiling. As part of the 2006 renovation the mosaic floors in the sculpture gallery were restored—most of the Victorian floors were covered in linoleum after the Second World War. After the success of the British Galleries, opened in 2001, it was decided to embark on a major redesign of all the galleries in the museum; this is known as "FuturePlan", and was created in consultation with the exhibition designers and masterplanners Metaphor. The plan is expected to take about ten years and was started in 2002. To date several galleries have been redesigned, notably, in 2002: the main Silver Gallery, Contemporary; in 2003: Photography, the main entrance, The Painting Galleries; in 2004: the tunnel to the subway leading to South Kensington tube station, New signage throughout the museum, architecture, V&A and RIBA reading rooms and stores, metalware, Members' Room, contemporary glass, the Gilbert Bayes sculpture gallery; in 2005: portrait miniatures, prints and drawings, displays in Room 117, the garden, sacred silver and stained glass; in 2006: Central Hall Shop, Islamic Middle East, the new café, sculpture galleries. Several designers and architects have been involved in this work. Eva Jiřičná designed the enhancements to the main entrance and rotunda, the new shop, the tunnel and the sculpture galleries. Gareth Hoskins was responsible for contemporary and architecture, Softroom, Islamic Middle East and the Members' Room, McInnes Usher McKnight Architects (MUMA) were responsible for the new Cafe and designed the new Medieval and Renaissance galleries which opened in 2009.
# Q: Who designed the new Medieval and Renaissance galleries which opened in 2009?
# P: Gareth Hoskins
#
#
# ----
#
#
#
#
# NER
#
# Change name everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    2 (2.0%)
#
# Example fails:
# C: Luther made his pronouncements from Wartburg in the context of rapid developments at Wittenberg, of which he was kept fully informed. Andreas Karlstadt, supported by the ex-Augustinian Gabriel Zwilling, embarked on a radical programme of reform there in June 1521, exceeding anything envisaged by Luther. The reforms provoked disturbances, including a revolt by the Augustinian friars against their prior, the smashing of statues and images in churches, and denunciations of the magistracy. After secretly visiting Wittenberg in early December 1521, Luther wrote A Sincere Admonition by Martin Luther to All Christians to Guard Against Insurrection and Rebellion. Wittenberg became even more volatile after Christmas when a band of visionary zealots, the so-called Zwickau prophets, arrived, preaching revolutionary doctrines such as the equality of man, adult baptism, and Christ's imminent return. When the town council asked Luther to return, he decided it was his duty to act.
# Q: Who asked Luther to return to the city?
# P: town council
#
# C: Benjamin made his pronouncements from Wartburg in the context of rapid developments at Wittenberg, of which he was kept fully informed. Andreas Karlstadt, supported by the ex-Augustinian Gabriel Zwilling, embarked on a radical programme of reform there in June 1521, exceeding anything envisaged by Benjamin. The reforms provoked disturbances, including a revolt by the Augustinian friars against their prior, the smashing of statues and images in churches, and denunciations of the magistracy. After secretly visiting Wittenberg in early December 1521, Benjamin wrote A Sincere Admonition by Martin Benjamin to All Christians to Guard Against Insurrection and Rebellion. Wittenberg became even more volatile after Christmas when a band of visionary zealots, the so-called Zwickau prophets, arrived, preaching revolutionary doctrines such as the equality of man, adult baptism, and Christ's imminent return. When the town council asked Benjamin to return, he decided it was his duty to act.
# Q: Who asked Benjamin to return to the city?
# P: the town council
#
# C: Ethan made his pronouncements from Wartburg in the context of rapid developments at Wittenberg, of which he was kept fully informed. Andreas Karlstadt, supported by the ex-Augustinian Gabriel Zwilling, embarked on a radical programme of reform there in June 1521, exceeding anything envisaged by Ethan. The reforms provoked disturbances, including a revolt by the Augustinian friars against their prior, the smashing of statues and images in churches, and denunciations of the magistracy. After secretly visiting Wittenberg in early December 1521, Ethan wrote A Sincere Admonition by Martin Ethan to All Christians to Guard Against Insurrection and Rebellion. Wittenberg became even more volatile after Christmas when a band of visionary zealots, the so-called Zwickau prophets, arrived, preaching revolutionary doctrines such as the equality of man, adult baptism, and Christ's imminent return. When the town council asked Ethan to return, he decided it was his duty to act.
# Q: Who asked Ethan to return to the city?
# P: the town council
#
#
# ----
# C: In 1881, Tesla moved to Budapest to work under Ferenc Puskás at a telegraph company, the Budapest Telephone Exchange. Upon arrival, Tesla realized that the company, then under construction, was not functional, so he worked as a draftsman in the Central Telegraph Office instead. Within a few months, the Budapest Telephone Exchange became functional and Tesla was allocated the chief electrician position. During his employment, Tesla made many improvements to the Central Station equipment and claimed to have perfected a telephone repeater or amplifier, which was never patented nor publicly described.
# Q: Where did Tesla work in Budapest?
# P: Budapest Telephone Exchange
#
# C: In 1881, Hailey moved to Budapest to work under Ferenc Puskás at a telegraph company, the Budapest Telephone Exchange. Upon arrival, Hailey realized that the company, then under construction, was not functional, so he worked as a draftsman in the Central Telegraph Office instead. Within a few months, the Budapest Telephone Exchange became functional and Hailey was allocated the chief electrician position. During his employment, Hailey made many improvements to the Central Station equipment and claimed to have perfected a telephone repeater or amplifier, which was never patented nor publicly described.
# Q: Where did Hailey work in Budapest?
# P: Central Telegraph Office
#
# C: In 1881, Ava moved to Budapest to work under Ferenc Puskás at a telegraph company, the Budapest Telephone Exchange. Upon arrival, Ava realized that the company, then under construction, was not functional, so he worked as a draftsman in the Central Telegraph Office instead. Within a few months, the Budapest Telephone Exchange became functional and Ava was allocated the chief electrician position. During his employment, Ava made many improvements to the Central Station equipment and claimed to have perfected a telephone repeater or amplifier, which was never patented nor publicly described.
# Q: Where did Ava work in Budapest?
# P: Central Telegraph Office
#
#
# ----
#
#
# Change location everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    11 (11.0%)
#
# Example fails:
# C: Imperialism has played an important role in the histories of Japan, Korea, the Assyrian Empire, the Chinese Empire, the Roman Empire, Greece, the Byzantine Empire, the Persian Empire, the Ottoman Empire, Ancient Egypt, the British Empire, India, and many other empires. Imperialism was a basic component to the conquests of Genghis Khan during the Mongol Empire, and of other war-lords. Historically recognized Muslim empires number in the dozens. Sub-Saharan Africa has also featured dozens of empires that predate the European colonial era, for example the Ethiopian Empire, Oyo Empire, Asante Union, Luba Empire, Lunda Empire, and Mutapa Empire. The Americas during the pre-Columbian era also had large empires such as the Aztec Empire and the Incan Empire.
# Q: How many Muslim empires have used imperialism?
# P: dozens
#
# C: Imperialism has played an important role in the histories of Japan, Korea, the Assyrian Empire, the Chinese Empire, the Roman Empire, Guinea-Bissau, the Byzantine Empire, the Persian Empire, the Ottoman Empire, Ancient Egypt, the British Empire, India, and many other empires. Imperialism was a basic component to the conquests of Genghis Khan during the Mongol Empire, and of other war-lords. Historically recognized Muslim empires number in the dozens. Sub-Saharan Africa has also featured dozens of empires that predate the European colonial era, for example the Ethiopian Empire, Oyo Empire, Asante Union, Luba Empire, Lunda Empire, and Mutapa Empire. The Americas during the pre-Columbian era also had large empires such as the Aztec Empire and the Incan Empire.
# Q: How many Muslim empires have used imperialism?
# P: number in the dozens
#
# C: Imperialism has played an important role in the histories of Japan, United States, the Assyrian Empire, the Chinese Empire, the Roman Empire, Greece, the Byzantine Empire, the Persian Empire, the Ottoman Empire, Ancient Egypt, the British Empire, India, and many other empires. Imperialism was a basic component to the conquests of Genghis Khan during the Mongol Empire, and of other war-lords. Historically recognized Muslim empires number in the dozens. Sub-Saharan Africa has also featured dozens of empires that predate the European colonial era, for example the Ethiopian Empire, Oyo Empire, Asante Union, Luba Empire, Lunda Empire, and Mutapa Empire. The Americas during the pre-Columbian era also had large empires such as the Aztec Empire and the Incan Empire.
# Q: How many Muslim empires have used imperialism?
# P: number in the dozens
#
#
# ----
# C: Citizenship of the EU has increasingly been seen as a "fundamental" status of member state nationals by the Court of Justice, and has accordingly increased the number of social services that people can access wherever they move. The Court has required that higher education, along with other forms of vocational training, should be more access, albeit with qualifying periods. In Commission v Austria the Court held that Austria was not entitled to restrict places in Austrian universities to Austrian students to avoid "structural, staffing and financial problems" if (mainly German) foreign students applied for places because there was little evidence of an actual problem.
# Q: In which case did the Court state that Austria was not allowed to hold places in Austrian schools exclusively for Austrian students?
# P: Commission v Austria
#
# C: Citizenship of the EU has increasingly been seen as a "fundamental" status of member state nationals by the Court of Justice, and has accordingly increased the number of social services that people can access wherever they move. The Court has required that higher education, along with other forms of vocational training, should be more access, albeit with qualifying periods. In Commission v Sint Maarten (Dutch part) the Court held that Sint Maarten (Dutch part) was not entitled to restrict places in Austrian universities to Austrian students to avoid "structural, staffing and financial problems" if (mainly German) foreign students applied for places because there was little evidence of an actual problem.
# Q: In which case did the Court state that Sint Maarten (Dutch part) was not allowed to hold places in Austrian schools exclusively for Austrian students?
# P: Commission v Sint Maarten
#
#
# ----
# C: In the spring of 1753, Paul Marin de la Malgue was given command of a 2,000-man force of Troupes de la Marine and Indians. His orders were to protect the King's land in the Ohio Valley from the British. Marin followed the route that Céloron had mapped out four years earlier, but where Céloron had limited the record of French claims to the burial of lead plates, Marin constructed and garrisoned forts. He first constructed Fort Presque Isle (near present-day Erie, Pennsylvania) on Lake Erie's south shore. He had a road built to the headwaters of LeBoeuf Creek. Marin constructed a second fort at Fort Le Boeuf (present-day Waterford, Pennsylvania), designed to guard the headwaters of LeBoeuf Creek. As he moved south, he drove off or captured British traders, alarming both the British and the Iroquois. Tanaghrisson, a chief of the Mingo, who were remnants of Iroquois and other tribes who had been driven west by colonial expansion. He intensely disliked the French (whom he accused of killing and eating his father). Traveling to Fort Le Boeuf, he threatened the French with military action, which Marin contemptuously dismissed.
# Q: Where was Marin's second fort constructed?
# P: Fort Le Boeuf (present-day Waterford, Pennsylvania
#
# C: In the spring of 1753, Paul Marin de la Malgue was given command of a 2,000-man force of Troupes de la Marine and Indians. His orders were to protect the King's land in the Ohio Valley from the British. Marin followed the route that Céloron had mapped out four years earlier, but where Céloron had limited the record of French claims to the burial of lead plates, Marin constructed and garrisoned forts. He first constructed Fort Presque Isle (near present-day Augusta-Richmond County, Pennsylvania) on Lake Augusta-Richmond County's south shore. He had a road built to the headwaters of LeBoeuf Creek. Marin constructed a second fort at Fort Le Boeuf (present-day Waterford, Pennsylvania), designed to guard the headwaters of LeBoeuf Creek. As he moved south, he drove off or captured British traders, alarming both the British and the Iroquois. Tanaghrisson, a chief of the Mingo, who were remnants of Iroquois and other tribes who had been driven west by colonial expansion. He intensely disliked the French (whom he accused of killing and eating his father). Traveling to Fort Le Boeuf, he threatened the French with military action, which Marin contemptuously dismissed.
# Q: Where was Marin's second fort constructed?
# P: Fort Le Boeuf
#
# C: In the spring of 1753, Paul Marin de la Malgue was given command of a 2,000-man force of Troupes de la Marine and Indians. His orders were to protect the King's land in the Ohio Valley from the British. Marin followed the route that Céloron had mapped out four years earlier, but where Céloron had limited the record of French claims to the burial of lead plates, Marin constructed and garrisoned forts. He first constructed Fort Presque Isle (near present-day Burien, Pennsylvania) on Lake Burien's south shore. He had a road built to the headwaters of LeBoeuf Creek. Marin constructed a second fort at Fort Le Boeuf (present-day Waterford, Pennsylvania), designed to guard the headwaters of LeBoeuf Creek. As he moved south, he drove off or captured British traders, alarming both the British and the Iroquois. Tanaghrisson, a chief of the Mingo, who were remnants of Iroquois and other tribes who had been driven west by colonial expansion. He intensely disliked the French (whom he accused of killing and eating his father). Traveling to Fort Le Boeuf, he threatened the French with military action, which Marin contemptuously dismissed.
# Q: Where was Marin's second fort constructed?
# P: Fort Le Boeuf
#
#
# ----
#
#
#
#
# Fairness
#
# M/F failure rates should be similar for different professions
# Test cases:      2000
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Dylan is not a nurse, Laura is.
# Q: Who is a nurse?
# A: Laura
# P: Dylan
#
# ----
# C: Donald is not a secretary, Andrea is.
# Q: Who is a secretary?
# A: Andrea
# P: Donald
#
# ----
# C: Melissa is not a nurse, Aaron is.
# Q: Who is a nurse?
# A: Aaron
# P: Melissa
#
# ----
#
#
#
#
# Temporal
#
# There was a change in profession
# Test cases:      482
# Test cases run:  100
# Fails (rate):    1 (1.0%)
#
# Example fails:
# C: Both Melissa and Mary were producers, but there was a change in Mary, who is now an analyst.
# Q: Who is an analyst?
# A: Mary
# P: Melissa and Mary
#
#
# ----
#
#
# Understanding before / after -> first / last.
# Test cases:      496
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Joshua became a academic before Kimberly did.
# Q: Who became a academic last?
# A: Kimberly
# P: Joshua
#
# C: Kimberly became a academic after Joshua did.
# Q: Who became a academic first?
# A: Joshua
# P: Kimberly
#
#
# ----
# C: Katherine became a investor before Steven did.
# Q: Who became a investor last?
# A: Steven
# P: Katherine
#
# C: Steven became a investor after Katherine did.
# Q: Who became a investor first?
# A: Katherine
# P: Steven
#
#
# ----
# C: Melissa became a accountant before Amanda did.
# Q: Who became a accountant last?
# A: Amanda
# P: Melissa
#
# C: Amanda became a accountant after Melissa did.
# Q: Who became a accountant first?
# A: Melissa
# P: Amanda
#
#
# ----
#
#
#
#
# Negation
#
# Negation in context, may or may not be in question
# Test cases:      499
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Heather is not an organizer. Jacob is.
# Q: Who is an organizer?
# A: Jacob
# P: Heather
#
# C: Jacob is an organizer. Heather is not.
# Q: Who is an organizer?
# A: Jacob
# P: Heather
#
#
# ----
# C: Shannon is not a producer. Laura is.
# Q: Who is a producer?
# A: Laura
# P: Shannon
#
# C: Laura is a producer. Shannon is not.
# Q: Who is not a producer?
# A: Shannon
# P: Laura
#
#
# ----
# C: Jason is not an actress. Olivia is.
# Q: Who is not an actress?
# A: Jason
# P: Olivia
#
# C: Olivia is an actress. Jason is not.
# Q: Who is an actress?
# A: Olivia
# P: Jason
#
# C: Olivia is an actress. Jason is not.
# Q: Who is not an actress?
# A: Jason
# P: Olivia
#
#
# ----
#
#
# Negation in question only.
# Test cases:      481
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Anthony is an activist. Ryan is an administrator.
# Q: Who is not an activist?
# A: Ryan
# P: Anthony
#
# C: Ryan is an administrator. Anthony is an activist.
# Q: Who is not an administrator?
# A: Anthony
# P: Ryan
#
#
# ----
# C: Emma is an organizer. Mary is an adviser.
# Q: Who is not an organizer?
# A: Mary
# P: Emma
#
# C: Emma is an organizer. Mary is an adviser.
# Q: Who is an adviser?
# A: Mary
# P: Emma
#
# C: Mary is an adviser. Emma is an organizer.
# Q: Who is an organizer?
# A: Emma
# P: Mary
#
#
# ----
# C: Abigail is an adviser. Robert is an organizer.
# Q: Who is not an adviser?
# A: Robert
# P: Abigail
#
# C: Robert is an organizer. Abigail is an adviser.
# Q: Who is not an organizer?
# A: Abigail
# P: Robert
#
#
# ----
#
#
#
#
# Coref
#
# Basic coref, he / she
# Test cases:      477
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Chad and Tiffany are friends. He is an executive, and she is an architect.
# Q: Who is an executive?
# A: Chad
# P: architect
#
# C: Chad and Tiffany are friends. He is an executive, and she is an architect.
# Q: Who is an architect?
# A: Tiffany
# P: Chad
#
# C: Tiffany and Chad are friends. He is an executive, and she is an architect.
# Q: Who is an executive?
# A: Chad
# P: architect
#
#
# ----
# C: Alexander and Monica are friends. He is an educator, and she is an escort.
# Q: Who is an escort?
# A: Monica
# P: Alexander and Monica
#
# C: Monica and Alexander are friends. He is an educator, and she is an escort.
# Q: Who is an educator?
# A: Alexander
# P: Monica and Alexander
#
# C: Monica and Alexander are friends. He is an educator, and she is an escort.
# Q: Who is an escort?
# A: Monica
# P: Monica and Alexander
#
#
# ----
# C: Ryan and Leslie are friends. He is an agent, and she is a photographer.
# Q: Who is an agent?
# A: Ryan
# P: photographer
#
# C: Ryan and Leslie are friends. He is an agent, and she is a photographer.
# Q: Who is a photographer?
# A: Leslie
# P: Ryan
#
# C: Leslie and Ryan are friends. He is an agent, and she is a photographer.
# Q: Who is an agent?
# A: Ryan
# P: photographer
#
#
# ----
#
#
# Basic coref, his / her
# Test cases:      500
# Test cases run:  100
# Fails (rate):    97 (97.0%)
#
# Example fails:
# C: Olivia and Samuel are friends. His mom is an intern.
# Q: Whose mom is an intern?
# A: Samuel
# P: Olivia and Samuel
#
#
# ----
# C: Steven and Madison are friends. Her mom is an escort.
# Q: Whose mom is an escort?
# A: Madison
# P: Steven and Madison
#
# C: Madison and Steven are friends. Her mom is an escort.
# Q: Whose mom is an escort?
# A: Madison
# P: Madison and Steven
#
#
# ----
# C: Jesse and April are friends. Her mom is an advisor.
# Q: Whose mom is an advisor?
# A: April
# P: Jesse and April
#
# C: April and Jesse are friends. Her mom is an advisor.
# Q: Whose mom is an advisor?
# A: April
# P: April and Jesse
#
#
# ----
#
#
# Former / Latter
# Test cases:      475
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Scott and Adam are friends. The former is an adviser.
# Q: Who is an adviser?
# A: Scott
# P: Scott and Adam are friends
#
# C: Adam and Scott are friends. The latter is an adviser.
# Q: Who is an adviser?
# A: Scott
# P: Adam and Scott are friends
#
# C: Scott and Adam are friends. The former is an adviser and the latter is a photographer.
# Q: Who is an adviser?
# A: Scott
# P: photographer
#
#
# ----
# C: Madison and Katherine are friends. The former is an editor.
# Q: Who is an editor?
# A: Madison
# P: Madison and Katherine
#
# C: Katherine and Madison are friends. The latter is an editor.
# Q: Who is an editor?
# A: Madison
# P: Katherine and Madison
#
# C: Madison and Katherine are friends. The former is an editor and the latter is an accountant.
# Q: Who is an editor?
# A: Madison
# P: accountant
#
#
# ----
# C: Brittany and John are friends. The former is a photographer.
# Q: Who is a photographer?
# A: Brittany
# P: Brittany and John
#
# C: John and Brittany are friends. The latter is a photographer.
# Q: Who is a photographer?
# A: Brittany
# P: John and Brittany
#
# C: Brittany and John are friends. The former is a photographer and the latter is an academic.
# Q: Who is a photographer?
# A: Brittany
# P: Brittany and John
#
#
# ----
#
#
#
#
# SRL
#
# Agent / object distinction
# Test cases:      497
# Test cases run:  100
# Fails (rate):    99 (99.0%)
#
# Example fails:
# C: Lisa notices Andrea.
# Q: Who is noticed?
# A: Andrea
# P: Lisa
#
# C: Andrea is noticed by Lisa.
# Q: Who notices?
# A: Lisa
# P: Andrea
#
#
# ----
# C: Rachel deserves Patrick.
# Q: Who is deserved?
# A: Patrick
# P: Rachel deserves Patrick
#
# C: Patrick is deserved by Rachel.
# Q: Who deserves?
# A: Rachel
# P: Patrick is deserved by Rachel
#
#
# ----
# C: William loves John.
# Q: Who is loved?
# A: John
# P: William
#
#
# ----
#
#
# Agent / object distinction with 3 agents
# Test cases:      483
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Jeffrey supports Amber. Amber supports Alexander.
# Q: Who supports Alexander?
# A: Amber
# P: Jeffrey supports Amber
#
# C: Jeffrey supports Amber. Alexander is supported by Amber.
# Q: Who supports Alexander?
# A: Amber
# P: Jeffrey
#
# C: Jeffrey supports Amber. Alexander is supported by Amber.
# Q: Who is supported by Jeffrey?
# A: Amber
# P: Alexander
#
#
# ----
# C: Alexis bothers Joseph. Joseph bothers Hannah.
# Q: Who is bothered by Joseph?
# A: Hannah
# P: Alexis
#
# C: Alexis bothers Joseph. Hannah is bothered by Joseph.
# Q: Who bothers Hannah?
# A: Joseph
# P: Alexis
#
# C: Alexis bothers Joseph. Hannah is bothered by Joseph.
# Q: Who is bothered by Alexis?
# A: Joseph
# P: Hannah
#
#
# ----
# C: Eric likes Alyssa. Alyssa likes Isabella.
# Q: Who likes Alyssa?
# A: Eric
# P: Eric likes Alyssa. Alyssa likes Isabella
#
# C: Eric likes Alyssa. Isabella is liked by Alyssa.
# Q: Who likes Alyssa?
# A: Eric
# P: Isabella
#
# C: Eric likes Alyssa. Isabella is liked by Alyssa.
# Q: Who likes Isabella?
# A: Alyssa
# P: Eric
#
#
# ----

# %%
suite.visual_summary_table()
# Out:
# Please wait as we prepare the table data...
# SuiteSummarizer(stats={'npassed': 0, 'nfailed': 0, 'nfiltered': 0}, test_infos=[{'name': 'A is COMP than B. Wh…
