# %%
import numpy as np

# %%
import checklist
from checklist.test_suite import TestSuite
import logging
logging.basicConfig(level=logging.ERROR)

# %%
from transformers import pipeline

# %%
model = pipeline("question-answering", model="./trained_model", device=0)

# %%
suite_path = '../checklist/release_data/squad/squad_suite.pkl'
suite = TestSuite.from_file(suite_path)

# %%
def predconfs(context_question_pairs):
    preds = []
    confs = []
    for c, q in context_question_pairs:
        try:
            p = model(question=q, context=c, truncation=True, )
        except:
            print('Failed', q)
            preds.append(' ')
            confs.append(1)
        preds.append(p['answer'])
        confs.append(p['score'])
    return preds, np.array(confs)

# %%
suite.run(predconfs, overwrite=True)   #add param n=100 for quicker testing
# Out:
# Running A is COMP than B. Who is more / less COMP?
# Predicting 988 examples
# Running Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Predicting 5964 examples
# Running size, shape, age, color
# Predicting 2000 examples
# Running Profession vs nationality
# Predicting 5000 examples
# Running Animal vs Vehicle
# Predicting 2000 examples
# Running Animal vs Vehicle v2
# Predicting 1984 examples
# Running Synonyms
# Predicting 1788 examples
# Running A is COMP than B. Who is antonym(COMP)? B
# Predicting 1984 examples
# Running A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Predicting 7856 examples
# Running Question typo
# Predicting 1000 examples
# Running Question contractions
# Predicting 1005 examples
# Running Add random sentence to context
# Predicting 1500 examples
# Running Change name everywhere
# Predicting 5500 examples
# Running Change location everywhere
# Predicting 5500 examples
# Running There was a change in profession
# Predicting 964 examples
# Running Understanding before / after -> first / last.
# Predicting 1984 examples
# Running Negation in context, may or may not be in question
# Predicting 1996 examples
# Running Negation in question only.
# Predicting 3848 examples
# Running M/F failure rates should be similar for different professions
# Predicting 2000 examples
# Running Basic coref, he / she
# Predicting 3816 examples
# Running Basic coref, his / her
# Predicting 1000 examples
# Running Former / Latter
# Predicting 1900 examples
# Running Agent / object distinction
# Predicting 1988 examples
# Running Agent / object distinction with 3 agents
# Predicting 7728 examples

# %%
def format_squad_with_context(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'C: %s\nQ: %s\n' % (c, q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret

# %%
suite.summary(format_example_fn=format_squad_with_context)
# Out:
# Vocabulary
#
# A is COMP than B. Who is more / less COMP?
# Test cases:      494
# Fails (rate):    492 (99.6%)
#
# Example fails:
# C: Jennifer is cooler than Charles.
# Q: Who is less cool?
# A: Charles
# P: Jennifer
#
#
# ----
# C: Tyler is cleaner than Sarah.
# Q: Who is less clean?
# A: Sarah
# P: Tyler
#
#
# ----
# C: Robert is darker than Melissa.
# Q: Who is less dark?
# A: Melissa
# P: Robert
#
#
# ----
#
#
# Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Test cases:      497
# Fails (rate):    497 (100.0%)
#
# Example fails:
# C: Zachary is hopeful about the project. Joseph is highly hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Zachary
# P: Joseph
#
# C: Joseph is highly hopeful about the project. Zachary is hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Zachary
# P: Joseph
#
# C: Joseph is highly hopeful about the project. Zachary is a little hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Zachary
# P: Joseph is highly hopeful about the project. Zachary
#
#
# ----
# C: Mark is a little enthusiastic about the project. Sara is enthusiastic about the project.
# Q: Who is most enthusiastic about the project?
# A: Sara
# P: Mark
#
# C: Sara is enthusiastic about the project. Mark is a little enthusiastic about the project.
# Q: Who is most enthusiastic about the project?
# A: Sara
# P: Mark
#
# C: Mark is a little enthusiastic about the project. Sara is very enthusiastic about the project.
# Q: Who is most enthusiastic about the project?
# A: Sara
# P: Mark
#
#
# ----
# C: Scott is excited about the project. Ethan is really excited about the project.
# Q: Who is least excited about the project?
# A: Scott
# P: Ethan
#
# C: Ethan is really excited about the project. Scott is excited about the project.
# Q: Who is least excited about the project?
# A: Scott
# P: Ethan is really excited about the project. Scott
#
# C: Ethan is really excited about the project. Scott is excited about the project.
# Q: Who is most excited about the project?
# A: Ethan
# P: Ethan is really excited about the project. Scott
#
#
# ----
#
#
#
#
# Taxonomy
#
# size, shape, age, color
# Test cases:      500
# Fails (rate):    493 (98.6%)
#
# Example fails:
# C: There is a box in the room. The box is big and orange.
# Q: What size is the box?
# A: big
# P: big and orange
#
# C: There is a big orange box in the room.
# Q: What size is the box?
# A: big
# P: orange
#
#
# ----
# C: There is a toy in the room. The toy is triangular and black.
# Q: What shape is the toy?
# A: triangular
# P: triangular and black
#
# C: There is a triangular black toy in the room.
# Q: What shape is the toy?
# A: triangular
# P: triangular black
#
#
# ----
# C: There is a box in the room. The box is round and yellow.
# Q: What shape is the box?
# A: round
# P: round and yellow
#
# C: There is a round yellow box in the room.
# Q: What shape is the box?
# A: round
# P: round yellow
#
#
# ----
#
#
# Profession vs nationality
# Test cases:      500
# Fails (rate):    353 (70.6%)
#
# Example fails:
# C: Anna is a Russian producer.
# Q: What is Anna's job?
# A: producer
# P: Russian producer
#
#
# ----
# C: William is an Indonesian artist.
# Q: What is William's job?
# A: artist
# P: Indonesian artist
#
#
# ----
# C: Timothy is a Pakistani author.
# Q: What is Timothy's job?
# A: author
# P: Pakistani author
#
#
# ----
#
#
# Animal vs Vehicle
# Test cases:      500
# Fails (rate):    442 (88.4%)
#
# Example fails:
# C: Ethan has a cat and a tractor.
# Q: What vehicle does Ethan have?
# A: tractor
# P: a cat and a tractor
#
#
# ----
# C: Noah has a rabbit and a car.
# Q: What vehicle does Noah have?
# A: car
# P: a rabbit
#
#
# ----
# C: Katherine has a hamster and a minivan.
# Q: What vehicle does Katherine have?
# A: minivan
# P: hamster and a minivan
#
# C: Katherine has a minivan and a hamster.
# Q: What animal does Katherine have?
# A: hamster
# P: minivan and a hamster
#
#
# ----
#
#
# Animal vs Vehicle v2
# Test cases:      496
# Fails (rate):    196 (39.5%)
#
# Example fails:
# C: Tiffany bought a fish. Zachary bought a minivan.
# Q: Who bought an animal?
# A: Tiffany
# P: Tiffany bought a fish. Zachary
#
#
# ----
# C: Aaron bought a fish. Matthew bought a bike.
# Q: Who bought an animal?
# A: Aaron
# P: Matthew
#
#
# ----
# C: Kevin bought a firetruck. Benjamin bought a hamster.
# Q: Who bought a vehicle?
# A: Kevin
# P: Benjamin
#
#
# ----
#
#
# Synonyms
# Test cases:      447
# Fails (rate):    15 (3.4%)
#
# Example fails:
# C: Katherine is very religious. Andrea is very joyful.
# Q: Who is spiritual?
# A: Katherine
# P: Katherine is very religious. Andrea
#
#
# ----
# C: Abigail is very happy. Andrew is very grateful.
# Q: Who is joyful?
# A: Abigail
# P: Andrew
#
#
# ----
# C: Danielle is very humble. Anthony is very courageous.
# Q: Who is modest?
# A: Danielle
# P: Danielle is very humble. Anthony
#
#
# ----
#
#
# A is COMP than B. Who is antonym(COMP)? B
# Test cases:      496
# Fails (rate):    496 (100.0%)
#
# Example fails:
# C: Sean is quieter than Jessica.
# Q: Who is louder?
# A: Jessica
# P: Sean
#
# C: Jessica is louder than Sean.
# Q: Who is quieter?
# A: Sean
# P: Jessica
#
#
# ----
# C: Olivia is dumber than Melissa.
# Q: Who is smarter?
# A: Melissa
# P: Olivia
#
# C: Melissa is smarter than Olivia.
# Q: Who is dumber?
# A: Olivia
# P: Melissa
#
#
# ----
# C: Kevin is sadder than Anthony.
# Q: Who is happier?
# A: Anthony
# P: Kevin
#
# C: Anthony is happier than Kevin.
# Q: Who is sadder?
# A: Kevin
# P: Anthony
#
#
# ----
#
#
# A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Test cases:      491
# Fails (rate):    491 (100.0%)
#
# Example fails:
# C: Dylan is less conservative than Sean.
# Q: Who is more conservative?
# A: Sean
# P: Dylan
#
# C: Dylan is less conservative than Sean.
# Q: Who is less progressive?
# A: Sean
# P: Dylan
#
# C: Sean is more conservative than Dylan.
# Q: Who is less conservative?
# A: Dylan
# P: Sean
#
#
# ----
# C: Mark is more offensive than Emily.
# Q: Who is more defensive?
# A: Emily
# P: Mark
#
# C: Emily is less offensive than Mark.
# Q: Who is less defensive?
# A: Mark
# P: Emily
#
# C: Mark is less defensive than Emily.
# Q: Who is less offensive?
# A: Emily
# P: Mark
#
#
# ----
# C: Andrew is more pessimistic than Aaron.
# Q: Who is less pessimistic?
# A: Aaron
# P: Andrew
#
# C: Aaron is less pessimistic than Andrew.
# Q: Who is more pessimistic?
# A: Andrew
# P: Aaron
#
# C: Aaron is more optimistic than Andrew.
# Q: Who is more pessimistic?
# A: Andrew
# P: Aaron
#
#
# ----
#
#
#
#
# Robustness
#
# Question typo
# Test cases:      500
# Fails (rate):    100 (20.0%)
#
# Example fails:
# C: On 13 June 1525, the couple was engaged with Johannes Bugenhagen, Justus Jonas, Johannes Apel, Philipp Melanchthon and Lucas Cranach the Elder and his wife as witnesses. On the evening of the same day, the couple was married by Bugenhagen. The ceremonial walk to the church and the wedding banquet were left out, and were made up two weeks later on 27 June.
# Q: When was the wedding banquet celebrated?
# P: 27 June
#
# C: On 13 June 1525, the couple was engaged with Johannes Bugenhagen, Justus Jonas, Johannes Apel, Philipp Melanchthon and Lucas Cranach the Elder and his wife as witnesses. On the evening of the same day, the couple was married by Bugenhagen. The ceremonial walk to the church and the wedding banquet were left out, and were made up two weeks later on 27 June.
# Q: Whne was the wedding banquet celebrated?
# P: Bugenhagen
#
#
# ----
# C: The largest share of Kenya's electricity supply comes from hydroelectric stations at dams along the upper Tana River, as well as the Turkwel Gorge Dam in the west. A petroleum-fired plant on the coast, geothermal facilities at Olkaria (near Nairobi), and electricity imported from Uganda make up the rest of the supply. Kenya's installed capacity stood at 1,142 megawatts between 2001 and 2003. The state-owned Kenya Electricity Generating Company (KenGen), established in 1997 under the name of Kenya Power Company, handles the generation of electricity, while Kenya Power handles the electricity transmission and distribution system in the country. Shortfalls of electricity occur periodically, when drought reduces water flow. To become energy sufficient, Kenya aims to build a nuclear power plant by 2017.
# Q: When was Kenya Electricity Generating Company established?
# P: 1997
#
# C: The largest share of Kenya's electricity supply comes from hydroelectric stations at dams along the upper Tana River, as well as the Turkwel Gorge Dam in the west. A petroleum-fired plant on the coast, geothermal facilities at Olkaria (near Nairobi), and electricity imported from Uganda make up the rest of the supply. Kenya's installed capacity stood at 1,142 megawatts between 2001 and 2003. The state-owned Kenya Electricity Generating Company (KenGen), established in 1997 under the name of Kenya Power Company, handles the generation of electricity, while Kenya Power handles the electricity transmission and distribution system in the country. Shortfalls of electricity occur periodically, when drought reduces water flow. To become energy sufficient, Kenya aims to build a nuclear power plant by 2017.
# Q: hWen was Kenya Electricity Generating Company established?
# P: Kenya Power Company
#
#
# ----
# C: An increase in imported cars into North America forced General Motors, Ford and Chrysler to introduce smaller and fuel-efficient models for domestic sales. The Dodge Omni / Plymouth Horizon from Chrysler, the Ford Fiesta and the Chevrolet Chevette all had four-cylinder engines and room for at least four passengers by the late 1970s. By 1985, the average American vehicle moved 17.4 miles per gallon, compared to 13.5 in 1970. The improvements stayed even though the price of a barrel of oil remained constant at $12 from 1974 to 1979. Sales of large sedans for most makes (except Chrysler products) recovered within two model years of the 1973 crisis. The Cadillac DeVille and Fleetwood, Buick Electra, Oldsmobile 98, Lincoln Continental, Mercury Marquis, and various other luxury oriented sedans became popular again in the mid-1970s. The only full-size models that did not recover were lower price models such as the Chevrolet Bel Air, and Ford Galaxie 500. Slightly smaller, mid-size models such as the Oldsmobile Cutlass, Chevrolet Monte Carlo, Ford Thunderbird and various other models sold well.
# Q: How many passengers can the Ford Fiesta accommodate?
# P: at least four
#
# C: An increase in imported cars into North America forced General Motors, Ford and Chrysler to introduce smaller and fuel-efficient models for domestic sales. The Dodge Omni / Plymouth Horizon from Chrysler, the Ford Fiesta and the Chevrolet Chevette all had four-cylinder engines and room for at least four passengers by the late 1970s. By 1985, the average American vehicle moved 17.4 miles per gallon, compared to 13.5 in 1970. The improvements stayed even though the price of a barrel of oil remained constant at $12 from 1974 to 1979. Sales of large sedans for most makes (except Chrysler products) recovered within two model years of the 1973 crisis. The Cadillac DeVille and Fleetwood, Buick Electra, Oldsmobile 98, Lincoln Continental, Mercury Marquis, and various other luxury oriented sedans became popular again in the mid-1970s. The only full-size models that did not recover were lower price models such as the Chevrolet Bel Air, and Ford Galaxie 500. Slightly smaller, mid-size models such as the Oldsmobile Cutlass, Chevrolet Monte Carlo, Ford Thunderbird and various other models sold well.
# Q: How many passengers can the Ford Feista accommodate?
# P: at least four passengers
#
#
# ----
#
#
# Question contractions
# Test cases:      500
# Fails (rate):    52 (10.4%)
#
# Example fails:
# C: In this work, one of his most emphatic statements on faith, he argued that every good work designed to attract God's favor is a sin. All humans are sinners by nature, he explained, and God's grace (which cannot be earned) alone can make them just. On 1 August 1521, Luther wrote to Melanchthon on the same theme: "Be a sinner, and let your sins be strong, but let your trust in Christ be stronger, and rejoice in Christ who is the victor over sin, death, and the world. We will commit sins while we are here, for this life is not a place where justice resides."
# Q: What does Luther write that this life doesn't have?
# P: justice
#
# C: In this work, one of his most emphatic statements on faith, he argued that every good work designed to attract God's favor is a sin. All humans are sinners by nature, he explained, and God's grace (which cannot be earned) alone can make them just. On 1 August 1521, Luther wrote to Melanchthon on the same theme: "Be a sinner, and let your sins be strong, but let your trust in Christ be stronger, and rejoice in Christ who is the victor over sin, death, and the world. We will commit sins while we are here, for this life is not a place where justice resides."
# Q: What does Luther write that this life does not have?
# P: justice resides
#
#
# ----
# C: Luther objected to a saying attributed to Johann Tetzel that "As soon as the coin in the coffer rings, the soul from purgatory (also attested as 'into heaven') springs."
# Q: How did Tetzel state that the soul could leave purgatory?
# P: coin in the coffer rings
#
# C: Luther objected to a saying attributed to Johann Tetzel that "As soon as the coin in the coffer rings, the soul from purgatory (also attested as 'into heaven') springs."
# Q: How'd Tetzel state that the soul could leave purgatory?
# P: As soon as the coin in the coffer rings
#
#
# ----
# C: For the first time, the Super Bowl 50 Host Committee and the NFL have openly sought disabled veteran and lesbian, gay, bisexual and transgender-owned businesses in Business Connect, the Super Bowl program that provides local companies with contracting opportunities in and around the Super Bowl. The host committee has already raised over $40 million through sponsors including Apple, Google, Yahoo!, Intel, Gap, Chevron, and Dignity Health.
# Q: What is the Super Bowl program called that gives local companies business opportunities for the Super Bowl?
# P: businesses in Business Connect
#
# C: For the first time, the Super Bowl 50 Host Committee and the NFL have openly sought disabled veteran and lesbian, gay, bisexual and transgender-owned businesses in Business Connect, the Super Bowl program that provides local companies with contracting opportunities in and around the Super Bowl. The host committee has already raised over $40 million through sponsors including Apple, Google, Yahoo!, Intel, Gap, Chevron, and Dignity Health.
# Q: What's the Super Bowl program called that gives local companies business opportunities for the Super Bowl?
# P: Business Connect
#
#
# ----
#
#
# Add random sentence to context
# Test cases:      500
# Fails (rate):    85 (17.0%)
#
# Example fails:
# C: The centre-left Australian Labor Party (ALP), the centre-right Liberal Party of Australia, the rural-based National Party of Australia, and the environmentalist Australian Greens are Victoria's main political parties. Traditionally, Labor is strongest in Melbourne's working class western and northern suburbs, and the regional cities of Ballarat, Bendigo and Geelong. The Liberals' main support lies in Melbourne's more affluent eastern and outer suburbs, and some rural and regional centres. The Nationals are strongest in Victoria's North Western and Eastern rural regional areas. The Greens, who won their first lower house seats in 2014, are strongest in inner Melbourne.
# Q: Which party is strongest in Victoria's northwestern and eastern regions?
# P: The Nationals
#
# C: As he defeated rival tribes, he did not drive away enemy soldiers and abandon the rest. The centre-left Australian Labor Party (ALP), the centre-right Liberal Party of Australia, the rural-based National Party of Australia, and the environmentalist Australian Greens are Victoria's main political parties. Traditionally, Labor is strongest in Melbourne's working class western and northern suburbs, and the regional cities of Ballarat, Bendigo and Geelong. The Liberals' main support lies in Melbourne's more affluent eastern and outer suburbs, and some rural and regional centres. The Nationals are strongest in Victoria's North Western and Eastern rural regional areas. The Greens, who won their first lower house seats in 2014, are strongest in inner Melbourne.
# Q: Which party is strongest in Victoria's northwestern and eastern regions?
# P: Nationals
#
#
# ----
# C: Mortgage bankers, accountants, and cost engineers are likely participants in creating an overall plan for the financial management of the building construction project. The presence of the mortgage banker is highly likely, even in relatively small projects since the owner's equity in the property is the most obvious source of funding for a building project. Accountants act to study the expected monetary flow over the life of the project and to monitor the payouts throughout the process. Cost engineers and estimators apply expertise to relate the work and materials involved to a proper valuation. Cost overruns with government projects have occurred when the contractor identified change orders or project changes that increased costs, which are not subject to competition from other firms as they have already been eliminated from consideration after the initial bid.
# Q: The presence of who is highly likely even in small projects?
# P: mortgage banker
#
# C: Proposals to connect the Cambridge campus with the new Allston campus include new and enlarged bridges, a shuttle service and/or a tram. Mortgage bankers, accountants, and cost engineers are likely participants in creating an overall plan for the financial management of the building construction project. The presence of the mortgage banker is highly likely, even in relatively small projects since the owner's equity in the property is the most obvious source of funding for a building project. Accountants act to study the expected monetary flow over the life of the project and to monitor the payouts throughout the process. Cost engineers and estimators apply expertise to relate the work and materials involved to a proper valuation. Cost overruns with government projects have occurred when the contractor identified change orders or project changes that increased costs, which are not subject to competition from other firms as they have already been eliminated from consideration after the initial bid.
# Q: The presence of who is highly likely even in small projects?
# P: the mortgage banker
#
#
# ----
# C: An early important political response to the opening of hostilities was the convening of the Albany Congress in June and July, 1754. The goal of the congress was to formalize a unified front in trade and negotiations with various Indians, since allegiance of the various tribes and nations was seen to be pivotal in the success in the war that was unfolding. The plan that the delegates agreed to was never ratified by the colonial legislatures nor approved of by the crown. Nevertheless, the format of the congress and many specifics of the plan became the prototype for confederation during the War of Independence.
# Q: What was the importance of the congress?
# P: allegiance of the various tribes and nations
#
# C: At the start of the war, the French North American colonies had a population of roughly 60,000 European settlers, compared with 2 million in the British North American colonies. An early important political response to the opening of hostilities was the convening of the Albany Congress in June and July, 1754. The goal of the congress was to formalize a unified front in trade and negotiations with various Indians, since allegiance of the various tribes and nations was seen to be pivotal in the success in the war that was unfolding. The plan that the delegates agreed to was never ratified by the colonial legislatures nor approved of by the crown. Nevertheless, the format of the congress and many specifics of the plan became the prototype for confederation during the War of Independence.
# Q: What was the importance of the congress?
# P: formalize a unified front in trade and negotiations with various Indians
#
#
# ----
#
#
#
#
# NER
#
# Change name everywhere
# Test cases:      500
# Fails (rate):    45 (9.0%)
#
# Example fails:
# C: Luther's other major works on the Jews were his 60,000-word treatise Von den Juden und Ihren Lügen (On the Jews and Their Lies), and Vom Schem Hamphoras und vom Geschlecht Christi (On the Holy Name and the Lineage of Christ), both published in 1543, three years before his death. Luther argued that the Jews were no longer the chosen people but "the devil's people", and referred to them with violent, vile language. Citing Deuteronomy 13, wherein Moses commands the killing of idolaters and the burning of their cities and property as an offering to God, Luther called for a "scharfe Barmherzigkeit" ("sharp mercy") against the Jews "to see whether we might save at least a few from the glowing flames." Luther advocated setting synagogues on fire, destroying Jewish prayerbooks, forbidding rabbis from preaching, seizing Jews' property and money, and smashing up their homes, so that these "envenomed worms" would be forced into labour or expelled "for all time". In Robert Michael's view, Luther's words "We are at fault in not slaying them" amounted to a sanction for murder. "God's anger with them is so intense," Luther concluded, "that gentle mercy will only tend to make them worse, while sharp mercy will reform them but little. Therefore, in any case, away with them!"
# Q: How near to his death was the work published?
# P: three years before
#
# C: Stephen's other major works on the Jews were his 60,000-word treatise Von den Juden und Ihren Lügen (On the Jews and Their Lies), and Vom Schem Hamphoras und vom Geschlecht Christi (On the Holy Name and the Lineage of Christ), both published in 1543, three years before his death. Stephen argued that the Jews were no longer the chosen people but "the devil's people", and referred to them with violent, vile language. Citing Deuteronomy 13, wherein Moses commands the killing of idolaters and the burning of their cities and property as an offering to God, Stephen called for a "scharfe Barmherzigkeit" ("sharp mercy") against the Jews "to see whether we might save at least a few from the glowing flames." Stephen advocated setting synagogues on fire, destroying Jewish prayerbooks, forbidding rabbis from preaching, seizing Jews' property and money, and smashing up their homes, so that these "envenomed worms" would be forced into labour or expelled "for all time". In Robert Michael's view, Stephen's words "We are at fault in not slaying them" amounted to a sanction for murder. "God's anger with them is so intense," Stephen concluded, "that gentle mercy will only tend to make them worse, while sharp mercy will reform them but little. Therefore, in any case, away with them!"
# Q: How near to his death was the work published?
# P: three years before his death
#
# C: Justin's other major works on the Jews were his 60,000-word treatise Von den Juden und Ihren Lügen (On the Jews and Their Lies), and Vom Schem Hamphoras und vom Geschlecht Christi (On the Holy Name and the Lineage of Christ), both published in 1543, three years before his death. Justin argued that the Jews were no longer the chosen people but "the devil's people", and referred to them with violent, vile language. Citing Deuteronomy 13, wherein Moses commands the killing of idolaters and the burning of their cities and property as an offering to God, Justin called for a "scharfe Barmherzigkeit" ("sharp mercy") against the Jews "to see whether we might save at least a few from the glowing flames." Justin advocated setting synagogues on fire, destroying Jewish prayerbooks, forbidding rabbis from preaching, seizing Jews' property and money, and smashing up their homes, so that these "envenomed worms" would be forced into labour or expelled "for all time". In Robert Michael's view, Justin's words "We are at fault in not slaying them" amounted to a sanction for murder. "God's anger with them is so intense," Justin concluded, "that gentle mercy will only tend to make them worse, while sharp mercy will reform them but little. Therefore, in any case, away with them!"
# Q: How near to his death was the work published?
# P: three years before his death
#
#
# ----
# C: The Lutheran theologian Franz Pieper observed that Luther's teaching about the state of the Christian's soul after death differed from the later Lutheran theologians such as Johann Gerhard. Lessing (1755) had earlier reached the same conclusion in his analysis of Lutheran orthodoxy on this issue.
# Q: What theologian differed in views about the soul from Luther?
# P: Johann Gerhard
#
# C: The Lutheran theologian John Gomez observed that Luther's teaching about the state of the Christian's soul after death differed from the later Lutheran theologians such as Johann Gerhard. Lessing (1755) had earlier reached the same conclusion in his analysis of Lutheran orthodoxy on this issue.
# Q: What theologian differed in views about the soul from Luther?
# P: John Gomez
#
#
# ----
# C: Tesla was a good friend of Francis Marion Crawford, Robert Underwood Johnson, Stanford White, Fritz Lowenstein, George Scherff, and Kenneth Swezey. In middle age, Tesla became a close friend of Mark Twain; they spent a lot of time together in his lab and elsewhere. Twain notably described Tesla's induction motor invention as "the most valuable patent since the telephone." In the late 1920s, Tesla also befriended George Sylvester Viereck, a poet, writer, mystic, and later, a Nazi propagandist. Tesla occasionally attended dinner parties held by Viereck and his wife.
# Q: Where did Tesla and Twain hang out?
# P: lab
#
# C: Brianna was a good friend of Francis Marion Crawford, Robert Underwood Johnson, Stanford White, Fritz Lowenstein, George Scherff, and Kenneth Swezey. In middle age, Brianna became a close friend of Mark Twain; they spent a lot of time together in his lab and elsewhere. Twain notably described Brianna's induction motor invention as "the most valuable patent since the telephone." In the late 1920s, Brianna also befriended George Sylvester Viereck, a poet, writer, mystic, and later, a Nazi propagandist. Brianna occasionally attended dinner parties held by Viereck and his wife.
# Q: Where did Brianna and Twain hang out?
# P: in his lab
#
# C: Catherine was a good friend of Francis Marion Crawford, Robert Underwood Johnson, Stanford White, Fritz Lowenstein, George Scherff, and Kenneth Swezey. In middle age, Catherine became a close friend of Mark Twain; they spent a lot of time together in his lab and elsewhere. Twain notably described Catherine's induction motor invention as "the most valuable patent since the telephone." In the late 1920s, Catherine also befriended George Sylvester Viereck, a poet, writer, mystic, and later, a Nazi propagandist. Catherine occasionally attended dinner parties held by Viereck and his wife.
# Q: Where did Catherine and Twain hang out?
# P: in his lab
#
#
# ----
#
#
# Change location everywhere
# Test cases:      500
# Fails (rate):    69 (13.8%)
#
# Example fails:
# C: The league announced on October 16, 2012, that the two finalists were Sun Life Stadium and Levi's Stadium. The South Florida/Miami area has previously hosted the event 10 times (tied for most with New Orleans), with the most recent one being Super Bowl XLIV in 2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX), held at Stanford Stadium in Stanford, California, won by the home team 49ers. The Miami bid depended on whether the stadium underwent renovations. However, on May 3, 2013, the Florida legislature refused to approve the funding plan to pay for the renovations, dealing a significant blow to Miami's chances.
# Q: What was the entity that stepped in and caused Miami's Sun Life Stadium to no longer be in the running to host Super Bowl 50?
# P: Stanford Stadium
#
# C: The league announced on October 16, 2012, that the two finalists were Sun Life Stadium and Levi's Stadium. The South Florida/Fort Lauderdale area has previously hosted the event 10 times (tied for most with New Orleans), with the most recent one being Super Bowl XLIV in 2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX), held at Stanford Stadium in Stanford, California, won by the home team 49ers. The Fort Lauderdale bid depended on whether the stadium underwent renovations. However, on May 3, 2013, the Florida legislature refused to approve the funding plan to pay for the renovations, dealing a significant blow to Fort Lauderdale's chances.
# Q: What was the entity that stepped in and caused Fort Lauderdale's Sun Life Stadium to no longer be in the running to host Super Bowl 50?
# P: the Florida legislature
#
# C: The league announced on October 16, 2012, that the two finalists were Sun Life Stadium and Levi's Stadium. The South Florida/Broomfield area has previously hosted the event 10 times (tied for most with New Orleans), with the most recent one being Super Bowl XLIV in 2010. The San Francisco Bay Area last hosted in 1985 (Super Bowl XIX), held at Stanford Stadium in Stanford, California, won by the home team 49ers. The Broomfield bid depended on whether the stadium underwent renovations. However, on May 3, 2013, the Florida legislature refused to approve the funding plan to pay for the renovations, dealing a significant blow to Broomfield's chances.
# Q: What was the entity that stepped in and caused Broomfield's Sun Life Stadium to no longer be in the running to host Super Bowl 50?
# P: The league
#
#
# ----
# C: The European Commission is the main executive body of the European Union. Article 17(1) of the Treaty on European Union states the Commission should "promote the general interest of the Union" while Article 17(3) adds that Commissioners should be "completely independent" and not "take instructions from any Government". Under article 17(2), "Union legislative acts may only be adopted on the basis of a Commission proposal, except where the Treaties provide otherwise." This means that the Commission has a monopoly on initiating the legislative procedure, although the Council is the "de facto catalyst of many legislative initiatives". The Parliament can also formally request the Commission to submit a legislative proposal but the Commission can reject such a suggestion, giving reasons. The Commission's President (currently an ex-Luxembourg Prime Minister, Jean-Claude Juncker) sets the agenda for the EU's work. Decisions are taken by a simple majority vote, usually through a "written procedure" of circulating the proposals and adopting if there are no objections.[citation needed] Since Ireland refused to consent to changes in the Treaty of Lisbon 2007, there remains one Commissioner for each of the 28 member states, including the President and the High Representative for Foreign and Security Policy (currently Federica Mogherini). The Commissioners (and most importantly, the portfolios they will hold) are bargained over intensively by the member states. The Commissioners, as a block, are then subject to a qualified majority vote of the Council to approve, and majority approval of the Parliament. The proposal to make the Commissioners be drawn from the elected Parliament, was not adopted in the Treaty of Lisbon. This means Commissioners are, through the appointment process, the unelected subordinates of member state governments.
# Q: Which authority figure is designated to schedule and set the work of the EU?
# P: Jean-Claude Juncker
#
# C: The European Commission is the main executive body of the European Union. Article 17(1) of the Treaty on European Union states the Commission should "promote the general interest of the Union" while Article 17(3) adds that Commissioners should be "completely independent" and not "take instructions from any Government". Under article 17(2), "Union legislative acts may only be adopted on the basis of a Commission proposal, except where the Treaties provide otherwise." This means that the Commission has a monopoly on initiating the legislative procedure, although the Council is the "de facto catalyst of many legislative initiatives". The Parliament can also formally request the Commission to submit a legislative proposal but the Commission can reject such a suggestion, giving reasons. The Commission's President (currently an ex-Isle of Man Prime Minister, Jean-Claude Juncker) sets the agenda for the EU's work. Decisions are taken by a simple majority vote, usually through a "written procedure" of circulating the proposals and adopting if there are no objections.[citation needed] Since Ireland refused to consent to changes in the Treaty of Lisbon 2007, there remains one Commissioner for each of the 28 member states, including the President and the High Representative for Foreign and Security Policy (currently Federica Mogherini). The Commissioners (and most importantly, the portfolios they will hold) are bargained over intensively by the member states. The Commissioners, as a block, are then subject to a qualified majority vote of the Council to approve, and majority approval of the Parliament. The proposal to make the Commissioners be drawn from the elected Parliament, was not adopted in the Treaty of Lisbon. This means Commissioners are, through the appointment process, the unelected subordinates of member state governments.
# Q: Which authority figure is designated to schedule and set the work of the EU?
# P: The Commission's President
#
# C: The European Commission is the main executive body of the European Union. Article 17(1) of the Treaty on European Union states the Commission should "promote the general interest of the Union" while Article 17(3) adds that Commissioners should be "completely independent" and not "take instructions from any Government". Under article 17(2), "Union legislative acts may only be adopted on the basis of a Commission proposal, except where the Treaties provide otherwise." This means that the Commission has a monopoly on initiating the legislative procedure, although the Council is the "de facto catalyst of many legislative initiatives". The Parliament can also formally request the Commission to submit a legislative proposal but the Commission can reject such a suggestion, giving reasons. The Commission's President (currently an ex-St. Lucia Prime Minister, Jean-Claude Juncker) sets the agenda for the EU's work. Decisions are taken by a simple majority vote, usually through a "written procedure" of circulating the proposals and adopting if there are no objections.[citation needed] Since Ireland refused to consent to changes in the Treaty of Lisbon 2007, there remains one Commissioner for each of the 28 member states, including the President and the High Representative for Foreign and Security Policy (currently Federica Mogherini). The Commissioners (and most importantly, the portfolios they will hold) are bargained over intensively by the member states. The Commissioners, as a block, are then subject to a qualified majority vote of the Council to approve, and majority approval of the Parliament. The proposal to make the Commissioners be drawn from the elected Parliament, was not adopted in the Treaty of Lisbon. This means Commissioners are, through the appointment process, the unelected subordinates of member state governments.
# Q: Which authority figure is designated to schedule and set the work of the EU?
# P: The Commission's President
#
#
# ----
# C: Some disagree with such double or triple non-French linguistic origins, arguing that for the word to have spread into common use in France, it must have originated in the French language. The "Hugues hypothesis" argues that the name was derived by association with Hugues Capet, king of France, who reigned long before the Reformation. He was regarded by the Gallicans and Protestants as a noble man who respected people's dignity and lives. Janet Gray and other supporters of the hypothesis suggest that the name huguenote would be roughly equivalent to little Hugos, or those who want Hugo.
# Q: Other theories of the word's origin can be generally classed as what?
# P: double or triple non-French
#
# C: Some disagree with such double or triple non-French linguistic origins, arguing that for the word to have spread into common use in Albania, it must have originated in the French language. The "Hugues hypothesis" argues that the name was derived by association with Hugues Capet, king of Albania, who reigned long before the Reformation. He was regarded by the Gallicans and Protestants as a noble man who respected people's dignity and lives. Janet Gray and other supporters of the hypothesis suggest that the name huguenote would be roughly equivalent to little Hugos, or those who want Hugo.
# Q: Other theories of the word's origin can be generally classed as what?
# P: noble man who respected people's dignity and lives
#
# C: Some disagree with such double or triple non-French linguistic origins, arguing that for the word to have spread into common use in Panama, it must have originated in the French language. The "Hugues hypothesis" argues that the name was derived by association with Hugues Capet, king of Panama, who reigned long before the Reformation. He was regarded by the Gallicans and Protestants as a noble man who respected people's dignity and lives. Janet Gray and other supporters of the hypothesis suggest that the name huguenote would be roughly equivalent to little Hugos, or those who want Hugo.
# Q: Other theories of the word's origin can be generally classed as what?
# P: noble man who respected people's dignity and lives
#
#
# ----
#
#
#
#
# Fairness
#
# M/F failure rates should be similar for different professions
# Test cases:      2000
# Fails (rate):    1508 (75.4%)
#
# Example fails:
# C: Daniel is not a secretary, Laura is.
# Q: Who is a secretary?
# A: Laura
# P: Daniel
#
# ----
# C: Hannah is not a CEO, Angel is.
# Q: Who is a CEO?
# A: Angel
# P: Hannah
#
# ----
# C: Brian is not a CEO, Jacqueline is.
# Q: Who is a CEO?
# A: Jacqueline
# P: Brian
#
# ----
#
#
#
#
# Temporal
#
# There was a change in profession
# Test cases:      482
# Fails (rate):    44 (9.1%)
#
# Example fails:
# C: Both Jeffrey and Mark were assistants, but there was a change in Jeffrey, who is now an academic.
# Q: Who is an academic?
# A: Jeffrey
# P: Jeffrey and Mark were assistants, but there was a change in Jeffrey
#
#
# ----
# C: Both James and Joseph were assistants, but there was a change in James, who is now an attorney.
# Q: Who is an attorney?
# A: James
# P: James and Joseph were assistants, but there was a change in James
#
# C: Both Joseph and James were assistants, but there was a change in James, who is now an attorney.
# Q: Who is an attorney?
# A: James
# P: Joseph and James were assistants, but there was a change in James
#
#
# ----
# C: Both Brian and Brittany were journalists, but there was a change in Brian, who is now an economist.
# Q: Who is an economist?
# A: Brian
# P: Brian and Brittany were journalists, but there was a change in Brian
#
#
# ----
#
#
# Understanding before / after -> first / last.
# Test cases:      496
# Fails (rate):    496 (100.0%)
#
# Example fails:
# C: Melissa became a interpreter before Stephanie did.
# Q: Who became a interpreter last?
# A: Stephanie
# P: Melissa
#
# C: Stephanie became a interpreter after Melissa did.
# Q: Who became a interpreter first?
# A: Melissa
# P: Stephanie
#
# C: Stephanie became a interpreter after Melissa did.
# Q: Who became a interpreter last?
# A: Stephanie
# P: Melissa
#
#
# ----
# C: Jacob became a accountant before Justin did.
# Q: Who became a accountant last?
# A: Justin
# P: Jacob
#
# C: Justin became a accountant after Jacob did.
# Q: Who became a accountant first?
# A: Jacob
# P: Justin
#
#
# ----
# C: Zachary became a activist before Jennifer did.
# Q: Who became a activist last?
# A: Jennifer
# P: Zachary
#
# C: Jennifer became a activist after Zachary did.
# Q: Who became a activist first?
# A: Zachary
# P: Jennifer
#
# C: Jennifer became a activist after Zachary did.
# Q: Who became a activist last?
# A: Jennifer
# P: Zachary
#
#
# ----
#
#
#
#
# Negation
#
# Negation in context, may or may not be in question
# Test cases:      499
# Fails (rate):    456 (91.4%)
#
# Example fails:
# C: Noah is not an advisor. Ryan is.
# Q: Who is an advisor?
# A: Ryan
# P: Noah
#
#
# ----
# C: Charles is not an attorney. Heather is.
# Q: Who is an attorney?
# A: Heather
# P: Charles
#
#
# ----
# C: Patrick is not a photographer. Madison is.
# Q: Who is a photographer?
# A: Madison
# P: Patrick
#
#
# ----
#
#
# Negation in question only.
# Test cases:      481
# Fails (rate):    481 (100.0%)
#
# Example fails:
# C: Rachel is an advisor. Alyssa is a producer.
# Q: Who is not an advisor?
# A: Alyssa
# P: Rachel
#
# C: Rachel is an advisor. Alyssa is a producer.
# Q: Who is not a producer?
# A: Rachel
# P: Alyssa
#
# C: Alyssa is a producer. Rachel is an advisor.
# Q: Who is not an advisor?
# A: Alyssa
# P: Rachel
#
#
# ----
# C: Alexis is an entrepreneur. Benjamin is an agent.
# Q: Who is not an entrepreneur?
# A: Benjamin
# P: Alexis
#
# C: Alexis is an entrepreneur. Benjamin is an agent.
# Q: Who is not an agent?
# A: Alexis
# P: Benjamin
#
# C: Benjamin is an agent. Alexis is an entrepreneur.
# Q: Who is not an entrepreneur?
# A: Benjamin
# P: Alexis
#
#
# ----
# C: Daniel is an educator. Angela is an administrator.
# Q: Who is not an educator?
# A: Angela
# P: Daniel
#
# C: Daniel is an educator. Angela is an administrator.
# Q: Who is not an administrator?
# A: Daniel
# P: Angela
#
# C: Angela is an administrator. Daniel is an educator.
# Q: Who is not an educator?
# A: Angela
# P: Daniel
#
#
# ----
#
#
#
#
# Coref
#
# Basic coref, he / she
# Test cases:      477
# Fails (rate):    477 (100.0%)
#
# Example fails:
# C: Cody and Victoria are friends. He is an entrepreneur, and she is a producer.
# Q: Who is an entrepreneur?
# A: Cody
# P: Cody and Victoria
#
# C: Cody and Victoria are friends. He is an entrepreneur, and she is a producer.
# Q: Who is a producer?
# A: Victoria
# P: Cody and Victoria
#
# C: Victoria and Cody are friends. He is an entrepreneur, and she is a producer.
# Q: Who is a producer?
# A: Victoria
# P: Cody
#
#
# ----
# C: Richard and Lindsey are friends. He is an entrepreneur, and she is an assistant.
# Q: Who is an entrepreneur?
# A: Richard
# P: Richard and Lindsey
#
# C: Richard and Lindsey are friends. He is an entrepreneur, and she is an assistant.
# Q: Who is an assistant?
# A: Lindsey
# P: Richard and Lindsey
#
# C: Lindsey and Richard are friends. He is an entrepreneur, and she is an assistant.
# Q: Who is an entrepreneur?
# A: Richard
# P: Lindsey and Richard
#
#
# ----
# C: Adam and Kristin are friends. He is an interpreter, and she is a photographer.
# Q: Who is an interpreter?
# A: Adam
# P: Adam and Kristin
#
# C: Adam and Kristin are friends. He is an interpreter, and she is a photographer.
# Q: Who is a photographer?
# A: Kristin
# P: Adam and Kristin
#
# C: Kristin and Adam are friends. He is an interpreter, and she is a photographer.
# Q: Who is an interpreter?
# A: Adam
# P: Kristin and Adam
#
#
# ----
#
#
# Basic coref, his / her
# Test cases:      500
# Fails (rate):    379 (75.8%)
#
# Example fails:
# C: Jordan and Stephanie are friends. His mom is an investor.
# Q: Whose mom is an investor?
# A: Jordan
# P: His mom
#
#
# ----
# C: Charles and Kayla are friends. Her mom is an academic.
# Q: Whose mom is an academic?
# A: Kayla
# P: Charles and Kayla
#
#
# ----
# C: Juan and Monica are friends. Her mom is an intern.
# Q: Whose mom is an intern?
# A: Monica
# P: Juan and Monica
#
# C: Monica and Juan are friends. Her mom is an intern.
# Q: Whose mom is an intern?
# A: Monica
# P: Monica and Juan
#
#
# ----
#
#
# Former / Latter
# Test cases:      475
# Fails (rate):    475 (100.0%)
#
# Example fails:
# C: Taylor and Alyssa are friends. The former is an advisor.
# Q: Who is an advisor?
# A: Taylor
# P: Taylor and Alyssa
#
# C: Alyssa and Taylor are friends. The latter is an advisor.
# Q: Who is an advisor?
# A: Taylor
# P: Alyssa and Taylor
#
# C: Taylor and Alyssa are friends. The former is an advisor and the latter is an administrator.
# Q: Who is an advisor?
# A: Taylor
# P: Taylor and Alyssa
#
#
# ----
# C: Jose and Lisa are friends. The former is an academic.
# Q: Who is an academic?
# A: Jose
# P: Jose and Lisa
#
# C: Lisa and Jose are friends. The latter is an academic.
# Q: Who is an academic?
# A: Jose
# P: Lisa and Jose
#
# C: Jose and Lisa are friends. The former is an academic and the latter is an editor.
# Q: Who is an academic?
# A: Jose
# P: editor
#
#
# ----
# C: Jose and Megan are friends. The former is an author.
# Q: Who is an author?
# A: Jose
# P: Jose and Megan
#
# C: Megan and Jose are friends. The latter is an author.
# Q: Who is an author?
# A: Jose
# P: Megan and Jose
#
# C: Jose and Megan are friends. The former is an author and the latter is an investigator.
# Q: Who is an author?
# A: Jose
# P: an investigator
#
#
# ----
#
#
#
#
# SRL
#
# Agent / object distinction
# Test cases:      497
# Fails (rate):    438 (88.1%)
#
# Example fails:
# C: Kyle likes Benjamin.
# Q: Who likes?
# A: Kyle
# P: Benjamin
#
# C: Benjamin is liked by Kyle.
# Q: Who is liked?
# A: Benjamin
# P: Benjamin is liked by Kyle
#
#
# ----
# C: Brandon supports Natalie.
# Q: Who is supported?
# A: Natalie
# P: Brandon supports Natalie
#
# C: Natalie is supported by Brandon.
# Q: Who is supported?
# A: Natalie
# P: Brandon
#
#
# ----
# C: Melissa follows Kevin.
# Q: Who is followed?
# A: Kevin
# P: Melissa follows Kevin
#
# C: Kevin is followed by Melissa.
# Q: Who is followed?
# A: Kevin
# P: Kevin is followed by Melissa
#
#
# ----
#
#
# Agent / object distinction with 3 agents
# Test cases:      483
# Fails (rate):    482 (99.8%)
#
# Example fails:
# C: Jonathan is trusted by Sean. Jonathan trusts Matthew.
# Q: Who is trusted by Jonathan?
# A: Matthew
# P: Sean
#
#
# ----
# C: Joshua trusts Mark. Mark trusts Robert.
# Q: Who is trusted by Mark?
# A: Robert
# P: Joshua trusts Mark. Mark trusts Robert
#
# C: Joshua trusts Mark. Robert is trusted by Mark.
# Q: Who is trusted by Joshua?
# A: Mark
# P: Mark. Robert
#
# C: Mark is trusted by Joshua. Mark trusts Robert.
# Q: Who is trusted by Mark?
# A: Robert
# P: Joshua
#
#
# ----
# C: Samantha attacks Dylan. Dylan attacks Tiffany.
# Q: Who attacks Dylan?
# A: Samantha
# P: Samantha attacks Dylan. Dylan attacks Tiffany
#
# C: Dylan is attacked by Samantha. Dylan attacks Tiffany.
# Q: Who attacks Dylan?
# A: Samantha
# P: Tiffany
#
# C: Dylan is attacked by Samantha. Tiffany is attacked by Dylan.
# Q: Who attacks Dylan?
# A: Samantha
# P: Tiffany
#
#
# ----

# %%
suite.visual_summary_table()
# Out:
# Please wait as we prepare the table data...
# SuiteSummarizer(stats={'npassed': 0, 'nfailed': 0, 'nfiltered': 0}, test_infos=[{'name': 'A is COMP than B. Wh…

# %%
test = suite.tests['Question typo']
test.run(predconfs, overwrite=True)
# Out:
# Predicting 1000 examples

# %%
test.summary()
# Out:
# Test cases:      500
# Fails (rate):    100 (20.0%)
#
# Example fails:
# Caris & Co. ("The Writers Guild of America strike that halted production of network programs for much of the 2007–08 season affected the network in 2007–08 and 2008–09, as various ABC shows that premiered in 2007, such as Dirty Sexy Money, Pushing Daisies, Eli Stone and Samantha Who?, did not live to see a third season; other series such as Boston Legal and the U.S. version of Life on Mars suffered from low viewership, despite the former, a spin off of The Practice, being a once-highlighted breakout series when it debuted in 2005. One of the network's strike-replacement programs during that time was the game show Duel, which premiered in December 2007. The program would become a minor success for the network during its initial six-episode run, which led ABC to renew Duel as a regular series starting in April 2008. However, Duel suffered from low viewership during its run as a regular series, and ABC canceled the program after sixteen episodes. On August 15, 2008, Disney denied rumors started by Caris & Co. that it would be selling the ten ABC owned-and-operated stations.", 'Who started rumors in 2008 that ABC would sell its ten owned-and-operated stations?')
# Caris & Co ("The Writers Guild of America strike that halted production of network programs for much of the 2007–08 season affected the network in 2007–08 and 2008–09, as various ABC shows that premiered in 2007, such as Dirty Sexy Money, Pushing Daisies, Eli Stone and Samantha Who?, did not live to see a third season; other series such as Boston Legal and the U.S. version of Life on Mars suffered from low viewership, despite the former, a spin off of The Practice, being a once-highlighted breakout series when it debuted in 2005. One of the network's strike-replacement programs during that time was the game show Duel, which premiered in December 2007. The program would become a minor success for the network during its initial six-episode run, which led ABC to renew Duel as a regular series starting in April 2008. However, Duel suffered from low viewership during its run as a regular series, and ABC canceled the program after sixteen episodes. On August 15, 2008, Disney denied rumors started by Caris & Co. that it would be selling the ten ABC owned-and-operated stations.", 'Who started rumors in 2008 that ABC would sell its ten owned-and-opreated stations?')
#
# ----
# The 1960s ("The 1960s would be marked by the rise of family-oriented series in an attempt by ABC to counterprogram its established competitors, but the decade was also marked by the network's gradual transition to color. On September 30, 1960, ABC premiered The Flintstones, another example of counterprogramming; although the animated series from William Hanna and Joseph Barbera was filmed in color from the beginning, it was initially broadcast in black-and-white, as ABC had not made the necessary technical upgrades to broadcast its programming in color at the time. The Flintstones allowed ABC to present a novelty, that of prime-time animated programming, but it also allowed the network to begin filling the hole opened by the conclusion of the Disney partnership by carrying family-oriented programming from other producers.", 'When did ABC begin making family-oriented series?')
# Flintstones ("The 1960s would be marked by the rise of family-oriented series in an attempt by ABC to counterprogram its established competitors, but the decade was also marked by the network's gradual transition to color. On September 30, 1960, ABC premiered The Flintstones, another example of counterprogramming; although the animated series from William Hanna and Joseph Barbera was filmed in color from the beginning, it was initially broadcast in black-and-white, as ABC had not made the necessary technical upgrades to broadcast its programming in color at the time. The Flintstones allowed ABC to present a novelty, that of prime-time animated programming, but it also allowed the network to begin filling the hole opened by the conclusion of the Disney partnership by carrying family-oriented programming from other producers.", 'Whne did ABC begin making family-oriented series?')
#
# ----
# 1598 ('Montpellier was among the most important of the 66 "villes de sûreté" that the Edict of 1598 granted to the Huguenots. The city\'s political institutions and the university were all handed over to the Huguenots. Tension with Paris led to a siege by the royal army in 1622. Peace terms called for the dismantling of the city\'s fortifications. A royal citadel was built and the university and consulate were taken over by the Catholic party. Even before the Edict of Alès (1629), Protestant rule was dead and the ville de sûreté was no more.[citation needed]', 'When was this proclamation issued?')
# 1622 ('Montpellier was among the most important of the 66 "villes de sûreté" that the Edict of 1598 granted to the Huguenots. The city\'s political institutions and the university were all handed over to the Huguenots. Tension with Paris led to a siege by the royal army in 1622. Peace terms called for the dismantling of the city\'s fortifications. A royal citadel was built and the university and consulate were taken over by the Catholic party. Even before the Edict of Alès (1629), Protestant rule was dead and the ville de sûreté was no more.[citation needed]', 'When was this proclamatio nissued?')
#
# ----
